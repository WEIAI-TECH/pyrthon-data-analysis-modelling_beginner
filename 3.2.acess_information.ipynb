# %% [markdown]
# <img src="./images/shouke_logo.png"
#      style="float: right"
#      width=100
#      style="padding-bottom:100px;"/>
# <br>
# <br>
#
# <table style="float:center;">
#     <tr>
#         <td>
#             <img src='./images/python-logo.png'width=130>
#         </td>
#         <td>
#             <img src='./images/pandas-logo.png'width=150>
#         </td>
#     </tr>
# </table>
#
# <h1 style='text-align: center;'>Accessing Basic Information of DataFrame </h1>
# <h2 style='text-align: center;'>Shouke Wei, Ph.D. Professor</h2>
# <h3 style='text-align: center;'>Email: shouke.wei@gmail.com</h3>

# %% [markdown]
# ## Objective
# - how to access basic information of dataframe

# %%
# Load the required libraries
import pandas as pd

# Read the data
df = pd.read_csv('./data/gdp_china_clean.csv')

# %% [markdown]
# ## 1. Access the first few rows of the DataFrame

# %%
df.head()
# Out:
#    Unnamed: 0   Province GDP ranking   Year    GDP (x10^12CNY)  \
# 0           0  Guangdong        First    2000         1.074125
# 1           1  Guangdong        First    2001         1.203925
# 2           2  Guangdong        First    2002         1.350242
# 3           3  Guangdong        First    2003         1.584464
# 4           4  Guangdong        First    2004         1.886462
#
#    population (x10^7 person)  fixed assets investment (x10^12 CNY)  \
# 0                      8.650                              0.314513
# 1                      8.733                              0.348443
# 2                      8.842                              0.385078
# 3                      8.963                              0.481320
# 4                        NaN                              0.587002
#
#    total imports and exports (x10^8CNY)  fiscal expenditure(x10^12CNY)  \
# 0                              1.408147                       0.108032
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0   Province GDP ranking   Year    GDP (x10^12CNY)  \
# 0           0  Guangdong        First    2000         1.074125
# 1           1  Guangdong        First    2001         1.203925
# 2           2  Guangdong        First    2002         1.350242
#
#    population (x10^7 person)  fixed assets investment (x10^12 CNY)  \
# 0                      8.650                              0.314513
# 1                      8.733                              0.348443
# 2                      8.842                              0.385078
#
#    total imports and exports (x10^8CNY)  fiscal expenditure(x10^12CNY)  \
# 0                              1.408147                       0.108032
# 1                             14.609701                       0.132133
# 2                              1.830169                       0.152108
#
#    urban disposal income per capita (x10^4CNY)
# 0                                     0.976157
# 1                                     1.041519
# ...

# %% [markdown]
# ## 2. Access the last few rows of the DataFrame

# %%
df.tail()
# Out:
#     Unnamed: 0 Province GDP ranking   Year    GDP (x10^12CNY)  \
# 90          90    Henan        Fifth    2014         3.493824
# 91          91    Henan        Fifth    2015         3.700216
# 92          92    Henan        Fifth    2016         4.047179
# 93          93    Henan        Fifth    2017         4.455283
# 94          94    Henan        Fifth    2018         4.805586
#
#     population (x10^7 person)  fixed assets investment (x10^12 CNY)  \
# 90                      9.436                              3.078217
# 91                      9.480                              3.566035
# 92                      9.532                              4.041509
# 93                      9.392                              4.449690
# 94                      9.360                              4.450960
#
#     total imports and exports (x10^8CNY)  fiscal expenditure(x10^12CNY)  \
# 90                              0.399111                       0.602869
# ...

# %%
df.tail(2)
# Out:
#     Unnamed: 0 Province GDP ranking   Year    GDP (x10^12CNY)  \
# 93          93    Henan        Fifth    2017         4.455283
# 94          94    Henan        Fifth    2018         4.805586
#
#     population (x10^7 person)  fixed assets investment (x10^12 CNY)  \
# 93                      9.392                               4.44969
# 94                      9.360                               4.45096
#
#     total imports and exports (x10^8CNY)  fiscal expenditure(x10^12CNY)  \
# 93                              0.000523                       0.821552
# 94                              0.551170                       0.921773
#
#     urban disposal income per capita (x10^4CNY)
# 93                                      2.95579
# 94                                      3.18742

# %% [markdown]
# ## 3. Random selection of DataFrame

# %%
df.sample(5)
# Out:
#     Unnamed: 0   Province GDP ranking   Year    GDP (x10^12CNY)  \
# 66          66   Zhejiang       Fourth    2009         2.299035
# 76          76      Henan        Fifth    2000         0.505299
# 77          77      Henan        Fifth    2001         0.553301
# 93          93      Henan        Fifth    2017         4.455283
# 11          11  Guangdong        First    2011         5.321028
#
#     population (x10^7 person)  fixed assets investment (x10^12 CNY)  \
# 66                      5.276                              1.074232
# 76                      9.488                              0.137774
# 77                      9.555                              0.154406
# 93                      9.392                              4.449690
# 11                     10.505                              1.706920
#
#     total imports and exports (x10^8CNY)  fiscal expenditure(x10^12CNY)  \
# 66                              1.282390                       0.265335
# ...

# %% [markdown]
# ## 4. Access all except few lines

# %%
df.head(-2)
# Out:
#     Unnamed: 0   Province GDP ranking   Year    GDP (x10^12CNY)  \
# 0            0  Guangdong        First    2000         1.074125
# 1            1  Guangdong        First    2001         1.203925
# 2            2  Guangdong        First    2002         1.350242
# 3            3  Guangdong        First    2003         1.584464
# 4            4  Guangdong        First    2004         1.886462
# ..         ...        ...          ...     ...              ...
# 88          88      Henan        Fifth    2012         2.959931
# 89          89      Henan        Fifth    2013         3.219130
# 90          90      Henan        Fifth    2014         3.493824
# 91          91      Henan        Fifth    2015         3.700216
# 92          92      Henan        Fifth    2016         4.047179
#
#     population (x10^7 person)  fixed assets investment (x10^12 CNY)  \
# 0                       8.650                              0.314513
# ...

# %%
df.tail(-3)
# Out:
#     Unnamed: 0   Province GDP ranking   Year    GDP (x10^12CNY)  \
# 3            3  Guangdong        First    2003         1.584464
# 4            4  Guangdong        First    2004         1.886462
# 5            5  Guangdong        First    2005         2.255737
# 6            6  Guangdong        First    2006         2.658776
# 7            7  Guangdong        First    2007         3.177701
# ..         ...        ...          ...     ...              ...
# 90          90      Henan        Fifth    2014         3.493824
# 91          91      Henan        Fifth    2015         3.700216
# 92          92      Henan        Fifth    2016         4.047179
# 93          93      Henan        Fifth    2017         4.455283
# 94          94      Henan        Fifth    2018         4.805586
#
#     population (x10^7 person)  fixed assets investment (x10^12 CNY)  \
# 3                       8.963                              0.481320
# ...

# %% [markdown]
# ## 5. A summary of DataFrame information
# - info(): highlights the total number of rows, names of the columns, their data type, and any missing value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 10 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   95 non-null     int64
#  1   Province                                     95 non-null     object
#  2   GDP ranking                                  95 non-null     object
#  3   Year                                         95 non-null     int64
#  4   GDP (x10^12CNY)                              95 non-null     float64
#  5   population (x10^7 person)                    93 non-null     float64
#  6   fixed assets investment (x10^12 CNY)         95 non-null     float64
#  7   total imports and exports (x10^8CNY)         95 non-null     float64
#  8   fiscal expenditure(x10^12CNY)                95 non-null     float64
# ...

# %% [markdown]
# ## 6. Access one column's date type

# %%
df['Year  '].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## 7. Check the column names

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Province', 'GDP ranking ', 'Year  ', 'GDP (x10^12CNY)',
#        'population (x10^7 person)', 'fixed assets investment (x10^12 CNY)',
#        'total imports and exports (x10^8CNY)', 'fiscal expenditure(x10^12CNY)',
#        'urban disposal income per capita (x10^4CNY)'],
#       dtype='object')

# %% [markdown]
# ## 8. Check the shape of the DataFrame

# %%
df.shape
# Out:
# (95, 10)

# %% [markdown]
# ## 9. Generate a summary of some descriptive statistics

# %%
df.describe()
# Out:
#        Unnamed: 0       Year    GDP (x10^12CNY)  population (x10^7 person)  \
# count   95.000000    95.000000        95.000000                  93.000000
# mean    47.000000  2009.000000         3.456443                   8.321032
# std     27.568098     5.506283         2.365092                   1.802813
# min      0.000000  2000.000000         0.505299                   4.680000
# 25%     23.500000  2004.000000         1.425301                   7.588000
# 50%     47.000000  2009.000000         3.093328                   9.194000
# 75%     70.500000  2014.000000         4.956176                   9.488000
# max     94.000000  2018.000000         9.727777                  10.999000
#
#        fixed assets investment (x10^12 CNY)  \
# count                             95.000000
# mean                               1.914406
# std                                1.558411
# min                                0.137774
# 25%                                0.588736
# ...

# %%
df.describe().T
# Out:
#                                              count         mean        std  \
# Unnamed: 0                                    95.0    47.000000  27.568098
# Year                                          95.0  2009.000000   5.506283
# GDP (x10^12CNY)                               95.0     3.456443   2.365092
# population (x10^7 person)                     93.0     8.321032   1.802813
# fixed assets investment (x10^12 CNY)          95.0     1.914406   1.558411
# total imports and exports (x10^8CNY)          95.0     2.122045   2.300531
# fiscal expenditure(x10^12CNY)                 95.0     0.448604   0.366626
# urban disposal income per capita (x10^4CNY)   95.0     2.204282   1.225310
#
#                                                      min          25%  \
# Unnamed: 0                                      0.000000    23.500000
# Year                                         2000.000000  2004.000000
# GDP (x10^12CNY)                                 0.505299     1.425301
# ...

# %%
df.to_csv('./results/describe_result.csv')
